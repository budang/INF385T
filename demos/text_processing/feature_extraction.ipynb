# %%
import json
import nltk
import pprint
import requests

from azure_cfg import ta_key

#nltk.download()

# %%
# set up global variables
subscription_key = ta_key

text_analytics_base_url = "https://westcentralus.api.cognitive.microsoft.com/text/analytics/v2.0/"
language_api_url = text_analytics_base_url + "languages"
sentiment_api_url = text_analytics_base_url + "sentiment"
key_phrase_api_url = text_analytics_base_url + "keyPhrases"

image_dir = '../images/'
train_image_dir = '../images/train/'
test_image_dir = '../images/test/'

# %%
# evaluate text "documents" using the Microsoft Azure Cognitive Services Text Analytics API
def analyze_text(documents):
    headers   = {"Ocp-Apim-Subscription-Key": subscription_key}
    
    # query API for language analysis
    response  = requests.post(language_api_url, headers=headers, json=documents)
    languages = response.json()
    
    # query API for sentiment analysis
    response  = requests.post(sentiment_api_url, headers=headers, json=documents)
    sentiments = response.json()
    
    # query API for key phrases extraction
    response  = requests.post(key_phrase_api_url, headers=headers, json=documents)
    key_phrases = response.json()
    
    return (languages, sentiments, key_phrases)

# %%
# conduct POS tagging and return counts of POS types
def pos_tag_text(documents):
    tag_counts = []
    for document in documents['documents']:
        text = nltk.word_tokenize(document['text'])
        tags = nltk.pos_tag(text)
        frequencies = nltk.FreqDist(tag for (word, tag) in tags)

        tag_count = {
            'ADJ': 0,
            'ADP': 0,
            'ADV': 0,
            'CONJ': 0,
            'DET': 0,
            'NOUN': 0,
            'NUM': 0,
            'PRT': 0,
            'PRON': 0,
            'VERB': 0,
            '.': 0,
            'X': 0
        }

        for tag, count in frequencies.most_common():
            tag_count[tag] = count
            
        tag_counts.append(tag_count)
        
    return tag_counts

# %%
# get the question documents from the training set
def get_questions():
    labels = json.load(open('../images/train.json'))
    
    documents = []
    for index, document in enumerate(labels):
        documents.append({
            'id': index,
            'text': document['question']
        })
    
    return {'documents': documents}

# %%
documents = get_questions()
pprint.pprint(documents)
# Out:
# {'documents': [{'id': 0, 'text': "What's the name of this product?"},
#                {'id': 1, 'text': 'Can you tell me what is in this can please?'},
#                {'id': 2,
#                 'text': 'Is this enchilada sauce or is this tomatoes?  Thank '
#                         'you.'},
#                {'id': 3, 'text': 'What is the captcha on this screenshot?'},
#                {'id': 4, 'text': 'What is this item?'},
#                {'id': 5, 'text': "What's this?"},
#                {'id': 6, 'text': 'What is in this bottle?'},
#                {'id': 7, 'text': 'This item.'},
#                {'id': 8, 'text': 'What color do these look?'},
#                {'id': 9, 'text': 'Surface look clean? Thank you.'},
#                {'id': 10, 'text': 'Is this.'},
#                {'id': 11,
#                 'text': 'What is the sodium content of this can of food?'},
#                {'id': 12, 'text': 'what is this?'},
#                {'id': 13, 'text': 'What kind of drink is this?'},
#                {'id': 14, 'text': 'What flavor are these?'},
#                {'id': 15, 'text': 'What color... what color is this skirt?'},
#                {'id': 16, 'text': 'How much money is on the table?'},
#                {'id': 17,
#                 'text': 'What is the name of this product? What is the name of '
#                         'this product?'},
#                {'id': 18, 'text': 'What is this? '},
#                {'id': 19,
#                 'text': 'Can I ask about anything or any information without '
#                         'taking any pictures?'},
#                {'id': 20, 'text': 'What is this game?'},
#                {'id': 21, 'text': 'Alright, and what does this label say?'},
#                {'id': 22, 'text': 'What is in this can?'},
#                {'id': 23, 'text': 'What is this movie?'},
#                {'id': 24,
#                 'text': 'Can you see the piece of mail and can you tell me who '
#                         'this mail is for?'},
#                {'id': 25, 'text': 'What is this a picture of?'},
#                {'id': 26, 'text': 'What is this?'},
#                {'id': 27,
#                 'text': 'Am I right when I say that this string is blank?'},
#                {'id': 28, 'text': 'What can is this?'},
#                {'id': 29, 'text': 'Can you tell what this says?'},
#                {'id': 30, 'text': 'What is in here?'},
#                {'id': 31, 'text': 'What does this box say?'},
#                {'id': 32,
#                 'text': 'What color furniture is that?  And is that nice table '
#                         'and chairs?'},
#                {'id': 33,
#                 'text': "This is a medication bottle and I'd just like to know "
#                         'if there is a label and dosage information visible. '
#                         'Thank you.'},
#                {'id': 34, 'text': 'Are these low cut or crew ?'},
#                {'id': 35, 'text': 'Do you see anything on this screen?'},
#                {'id': 36, 'text': 'How much money is this?'},
#                {'id': 37, 'text': 'What brand are these speakers?'},
#                {'id': 38, 'text': "What's the name of this CD?"},
#                {'id': 39, 'text': 'What seasoning is this?'},
#                {'id': 40, 'text': 'What is on the bar code?'},
#                {'id': 41, 'text': 'What kind of jerky is this? '},
#                {'id': 42, 'text': 'What is this? No, wait.'},
#                {'id': 43, 'text': 'What is this spice?'},
#                {'id': 44, 'text': 'What is this, please?'},
#                {'id': 45, 'text': 'What is this?'},
#                {'id': 46, 'text': 'What is this?'},
#                {'id': 47,
#                 'text': 'Does the back of this box show what languages are '
#                         'supported in the movie?'},
#                {'id': 48, 'text': 'What is this?'},
#                {'id': 49, 'text': 'What is this?'},
#                {'id': 50,
#                 'text': 'Can you tell me the flavor of this yogurt please?'},
#                {'id': 51, 'text': 'is this cookie dough?'},
#                {'id': 52, 'text': 'What is this?'},
#                {'id': 53,
#                 'text': 'What is in this card and is it right side up or '
#                         'upside down? Thank you.'},
#                {'id': 54, 'text': 'Who is this?'},
#                {'id': 55, 'text': "What's the name of that, please?"},
#                {'id': 56,
#                 'text': 'Please describe the pattern and color of this bag.'},
#                {'id': 57, 'text': 'Test one two, test one two'},
#                {'id': 58, 'text': 'Can you read the name on that syrup bottle'},
#                {'id': 59, 'text': 'What is this a picture of?'},
#                {'id': 60, 'text': 'What is this?'},
#                {'id': 61, 'text': 'What type of chips are this?'},
#                {'id': 62, 'text': 'What color is the phone?'},
#                {'id': 63,
#                 'text': 'what has this picture got in it, what kind of things? '
#                         'What kind of stuff?'},
#                {'id': 64, 'text': 'What flavor is this, please?'},
#                {'id': 65, 'text': 'When does this expire?'},
#                {'id': 66,
#                 'text': 'Is this instant or cook and serve pudding? And what '
#                         'flavor is it?'},
#                {'id': 67, 'text': 'What kind of chips are these?'},
#                {'id': 68, 'text': 'can you tell me what screen is this?'},
#                {'id': 69, 'text': 'What canned good is this? '},
#                {'id': 70, 'text': 'What does the display say?'},
#                {'id': 71, 'text': 'What is the expiration date?'},
#                {'id': 72,
#                 'text': 'Ok hope it works this time. What kind of soup is '
#                         'this?'},
#                {'id': 73, 'text': 'What are these called?'},
#                {'id': 74,
#                 'text': 'I would like to know what this jar contains, please. '
#                         'Thank you.'},
#                {'id': 75,
#                 'text': 'Good morning could you please tell me what is in the '
#                         'can in my right hand. Thanks for your assistance.'},
#                {'id': 76, 'text': 'What kind of soda is that please?'},
#                {'id': 77, 'text': 'What kind of drink is it?'},
#                {'id': 78, 'text': 'Is that 7-up?'},
#                {'id': 79,
#                 'text': 'Hi is there a Speedo logo on the side of the swimming '
#                         'hat?'},
#                {'id': 80, 'text': 'What is this in front of me?'},
#                {'id': 81, 'text': 'Is my - is my light on?'},
#                {'id': 82, 'text': 'What is in this jar? What type of food?'},
#                {'id': 83, 'text': 'What am I looking at?'},
#                {'id': 84, 'text': 'How much do you charge for this service?'},
#                {'id': 85, 'text': 'What is this'},
#                {'id': 86, 'text': 'what color is his shirt'},
#                {'id': 87, 'text': 'What is my favorite dog?'},
#                {'id': 88, 'text': 'What is this island?'},
#                {'id': 89, 'text': 'What is this?'},
#                {'id': 90,
#                 'text': 'Can you please tell me if you see the headphones in '
#                         'the photo? '},
#                {'id': 91, 'text': 'Guy look like in this picture.'},
#                {'id': 92, 'text': 'What type of tree is this?'},
#                {'id': 93, 'text': 'What is this?'},
#                {'id': 94, 'text': 'What is this bottle?'},
#                {'id': 95, 'text': 'What is in the contents of this tube?'},
#                {'id': 96, 'text': 'What is this, please?'},
#                {'id': 97, 'text': 'where does this water come from'},
#                {'id': 98,
#                 'text': 'Hi, what can you see in this page that I have scanned '
#                         'with my phone camera?'},
#                {'id': 99, 'text': 'Tell me what spice this is please.'},
#                {'id': 100, 'text': 'What kind of snacks are these?'},
#                {'id': 101, 'text': 'What is the title of this book? '},
#                {'id': 102, 'text': 'What golf course logo is this from?'},
#                {'id': 103, 'text': 'How much money is it?'},
#                {'id': 104, 'text': 'What is this?'},
#                {'id': 105, 'text': "Tell me, what's this thing?"},
#                {'id': 106, 'text': 'What is on the front of my shirt?'},
#                {'id': 107,
#                 'text': "please if you could let me know which bottle i'm "
#                         'looking at i would appreciate it i need to know if '
#                         'this is my melatonin bottle or my vicodin bottle '
#                         'thank you.'},
#                {'id': 108, 'text': 'What is this?'},
#                {'id': 109,
#                 'text': 'I was setting up my chest board when a chest piece '
#                         'fell off it. Where did it roll?'},
#                {'id': 110, 'text': 'What does the sky look like? Thank you.'},
#                {'id': 111,
#                 'text': 'How many calories are in this bottle of beer?'},
#                {'id': 112, 'text': 'Can you tell me what this is?'},
#                {'id': 113, 'text': 'What is that?'},
#                {'id': 114, 'text': 'What kind of coffee is this?'},
#                {'id': 115, 'text': 'Is this butter salted or unsalted?'},
#                {'id': 116, 'text': 'What colors are in this sweater?'},
#                {'id': 117, 'text': 'What is that?'},
#                {'id': 118,
#                 'text': "I've changed the box, or turned it around.  Can you "
#                         'make the expiration date out now?'},
#                {'id': 119, 'text': "What's on this T.V. screen?"},
#                {'id': 120,
#                 'text': 'Is this whiskey Glenburgie, or Cragganmore what '
#                         'information can you read on the label? Thank you.'},
#                {'id': 121, 'text': 'What is this please?'},
#                {'id': 122, 'text': 'What color is this shirt?'},
#                {'id': 123, 'text': 'What can is this?'},
#                {'id': 124, 'text': 'What is in this bottle? '},
#                {'id': 125, 'text': 'What is the expiration date on this milk?'},
#                {'id': 126, 'text': 'What is this?'},
#                {'id': 127, 'text': 'What color is this shirt?'},
#                {'id': 128, 'text': 'Whats this?'},
#                {'id': 129, 'text': 'Which shirt is green?'},
#                {'id': 130, 'text': 'What is this item?'},
#                {'id': 131,
#                 'text': 'Hi is the can of soft drink in my right hand Pepsi or '
#                         'Coke or Root Beer?'},
#                {'id': 132,
#                 'text': 'What is the battery status? Is that better?'},
#                {'id': 133, 'text': 'What book is this?'},
#                {'id': 134, 'text': 'What is this a picture of?'},
#                {'id': 135, 'text': 'What is this?'},
#                {'id': 136, 'text': 'What is in this can?'},
#                {'id': 137, 'text': 'What kind of box is this?'},
#                {'id': 138, 'text': 'what kind of soda is this'},
#                {'id': 139, 'text': 'What is this? '},
#                {'id': 140, 'text': 'Can you tell me what this box says?'},
#                {'id': 141, 'text': 'What is that, please?'},
#                {'id': 142, 'text': 'What is this?'},
#                {'id': 143,
#                 'text': 'Is this labeled as pouch A or pouch B? Thank you'},
#                {'id': 144, 'text': 'What kind of tea is this?'},
#                {'id': 145, 'text': "What's this?"},
#                {'id': 146, 'text': 'What is this tablet please?'},
#                {'id': 147, 'text': 'What is in my refrigerator?'},
#                {'id': 148, 'text': 'What is this picture on my shirt?'},
#                {'id': 149,
#                 'text': 'What time is it and what kind of clock is it?'},
#                {'id': 150, 'text': 'What is this?'},
#                {'id': 151, 'text': 'Please tell me what is this picture?'},
#                {'id': 152,
#                 'text': 'Can you please tell me what kind of coffee or tea '
#                         'this is?'},
#                {'id': 153, 'text': 'What is this bottle?'},
#                {'id': 154,
#                 'text': 'Can you tell me what kind of soda this is?'},
#                {'id': 155,
#                 'text': 'Can you tell me what the name on this tube is?'},
#                {'id': 156, 'text': "What's in the can?"},
#                {'id': 157, 'text': "What's on the outside of this box?"},
#                {'id': 158, 'text': 'what is this coin? '},
#                {'id': 159, 'text': 'What type of pills are in this bottle?'},
#                {'id': 160, 'text': 'What flavor of juice is this? Thank you.'},
#                {'id': 161, 'text': 'What is this?'},
#                {'id': 162, 'text': 'What color are my shoes?'},
#                {'id': 163, 'text': 'What this student planner?'},
#                {'id': 164, 'text': "What's in this can?"},
#                {'id': 165, 'text': 'What color is this sweater'},
#                {'id': 166, 'text': 'What is this?'},
#                {'id': 167, 'text': 'what kind of popsicle is this?'},
#                {'id': 168, 'text': 'What is this?'},
#                {'id': 169,
#                 'text': 'Can you please tell me what color this shirt is? '
#                         'Thank you.'},
#                {'id': 170, 'text': 'What? What is this?'},
#                {'id': 171, 'text': 'Please tell me whats in this can.'},
#                {'id': 172, 'text': 'What is this?'},
#                {'id': 173, 'text': 'What is this?'},
#                {'id': 174, 'text': 'What is this CD?'},
#                {'id': 175, 'text': 'What is that?'},
#                {'id': 176, 'text': 'Whats the model number?'},
#                {'id': 177, 'text': 'What soap is this?'},
#                {'id': 178, 'text': 'What is this item.'},
#                {'id': 179, 'text': 'What is this photo?'},
#                {'id': 180, 'text': 'What is the captcha image?'},
#                {'id': 181, 'text': 'Do you read the text on this card?'},
#                {'id': 182, 'text': 'Use this.'},
#                {'id': 183, 'text': 'What is it'},
#                {'id': 184, 'text': 'What color are these jeans'},
#                {'id': 185, 'text': "What's in this basket?"},
#                {'id': 186, 'text': 'Hi, what does the logo say?'},
#                {'id': 187, 'text': 'What flavor is this?'},
#                {'id': 188, 'text': 'What is this?'},
#                {'id': 189, 'text': 'Is this like on or off?'},
#                {'id': 190,
#                 'text': 'What are the instructions for using this product?'},
#                {'id': 191, 'text': "Oh, what's this?"},
#                {'id': 192, 'text': 'What is in this can'},
#                {'id': 193, 'text': 'What is the name of this game'},
#                {'id': 194, 'text': 'What is this'},
#                {'id': 195, 'text': 'What is in this can?'},
#                {'id': 196, 'text': 'What is this?'},
#                {'id': 197,
#                 'text': "What flavor is this Gevalia coffee? It's the last "
#                         'one.'},
#                {'id': 198, 'text': 'Hi, what kind of can is this? '},
#                {'id': 199, 'text': 'What is this?'}]}

# %%
languages, sentiments, key_phrases = analyze_text(documents)
languages, sentiments, key_phrases = languages['documents'], sentiments['documents'], key_phrases['documents']

tag_counts = pos_tag_text(documents)

# %%
features = []
for i in range(len(documents['documents'])):
    analysis = {
        'language': languages[i]['detectedLanguages'][0]['iso6391Name'],
        'sentiment': sentiments[i]['score'],
        'numKeyPhrases': len(key_phrases[i]['keyPhrases'])
    }
    features.append({**analysis, **tag_counts[i]})

# %%
from pandas import DataFrame
from IPython.display import display

df = DataFrame(data=features)
display(df)
# Out:
#        ,  .    :  ADJ  ADP  ADV   CC  CD  CONJ  DET    ...      VBP  VBZ  \
# 0    NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 1    NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 2    NaN  2  NaN    0    0    0  1.0 NaN     0    0    ...      NaN  2.0
# 3    NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 4    NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 5    NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 6    NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 7    NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  NaN
# 8    NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      1.0  NaN
# 9    NaN  2  NaN    0    0    0  NaN NaN     0    0    ...      NaN  NaN
# 10   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 11   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 12   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 13   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 14   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      1.0  NaN
# 15   NaN  1  1.0    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 16   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 17   NaN  2  NaN    0    0    0  NaN NaN     0    0    ...      NaN  2.0
# 18   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 19   NaN  1  NaN    0    0    0  1.0 NaN     0    0    ...      NaN  NaN
# 20   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 21   1.0  1  NaN    0    0    0  1.0 NaN     0    0    ...      NaN  1.0
# 22   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 23   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 24   NaN  1  NaN    0    0    0  1.0 NaN     0    0    ...      NaN  1.0
# 25   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 26   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 27   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      2.0  1.0
# 28   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 29   NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# ..   ... ..  ...  ...  ...  ...  ...  ..   ...  ...    ...      ...  ...
# 170  NaN  2  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 171  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  NaN
# 172  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 173  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 174  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 175  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 176  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  NaN
# 177  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 178  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 179  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 180  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 181  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      1.0  NaN
# 182  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  NaN
# 183  NaN  0  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 184  NaN  0  NaN    0    0    0  NaN NaN     0    0    ...      1.0  NaN
# 185  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 186  1.0  1  NaN    0    0    0  NaN NaN     0    0    ...      1.0  1.0
# 187  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 188  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 189  NaN  1  NaN    0    0    0  1.0 NaN     0    0    ...      NaN  1.0
# 190  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      1.0  NaN
# 191  1.0  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 192  NaN  0  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 193  NaN  0  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 194  NaN  0  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 195  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 196  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 197  NaN  2  NaN    0    0    0  NaN NaN     0    0    ...      NaN  2.0
# 198  1.0  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
# 199  NaN  1  NaN    0    0    0  NaN NaN     0    0    ...      NaN  1.0
#
#      VERB  WDT   WP  WRB  X  language  numKeyPhrases  sentiment
# 0       0  NaN  1.0  NaN  0        en              1   0.863549
# 1       0  NaN  1.0  NaN  0        en              0   0.764013
# 2       0  NaN  NaN  NaN  0        en              2   0.984945
# 3       0  NaN  1.0  NaN  0        en              2   0.268598
# 4       0  NaN  1.0  NaN  0        en              1   0.500000
# 5       0  NaN  1.0  NaN  0        en              0   0.839447
# 6       0  NaN  1.0  NaN  0        en              1   0.194486
# 7       0  NaN  NaN  NaN  0        en              1   0.754812
# 8       0  NaN  1.0  NaN  0        en              1   0.898420
# 9       0  NaN  NaN  NaN  0        en              1   0.985198
# 10      0  NaN  NaN  NaN  0        en              0   0.827428
# 11      0  NaN  1.0  NaN  0        en              2   0.890301
# 12      0  NaN  1.0  NaN  0        en              0   0.210352
# 13      0  NaN  1.0  NaN  0        en              1   0.765828
# 14      0  NaN  1.0  NaN  0        en              1   0.759195
# 15      0  NaN  2.0  NaN  0        en              2   0.783431
# 16      0  NaN  NaN  1.0  0        en              2   0.763626
# 17      0  NaN  2.0  NaN  0        en              1   0.836794
# 18      0  NaN  1.0  NaN  0        en              0   0.210352
# 19      0  NaN  NaN  NaN  0        en              2   0.825090
# 20      0  NaN  1.0  NaN  0        en              1   0.689596
# 21      0  NaN  1.0  NaN  0        en              1   0.810212
# 22      0  NaN  1.0  NaN  0        en              0   0.829039
# 23      0  NaN  1.0  NaN  0        en              1   0.883873
# 24      0  NaN  1.0  NaN  0        en              1   0.832176
# 25      0  NaN  1.0  NaN  0        en              1   0.797583
# 26      0  NaN  1.0  NaN  0        en              0   0.210352
# 27      0  NaN  NaN  1.0  0        en              1   0.730145
# 28      0  NaN  1.0  NaN  0        en              0   0.803821
# 29      0  NaN  1.0  NaN  0        en              0   0.500000
# ..    ...  ...  ...  ... ..       ...            ...        ...
# 170     0  NaN  2.0  NaN  0        en              0   0.222501
# 171     0  NaN  NaN  NaN  0        en              1   0.779783
# 172     0  NaN  1.0  NaN  0        en              0   0.210352
# 173     0  NaN  1.0  NaN  0        en              0   0.210352
# 174     0  NaN  1.0  NaN  0        en              1   0.762083
# 175     0  NaN  1.0  NaN  0        en              0   0.204724
# 176     0  NaN  NaN  NaN  0        en              1   0.292571
# 177     0  NaN  1.0  NaN  0        en              1   0.707107
# 178     0  NaN  1.0  NaN  0        en              1   0.500000
# 179     0  NaN  1.0  NaN  0        en              1   0.782161
# 180     0  NaN  1.0  NaN  0        en              1   0.251336
# 181     0  NaN  NaN  NaN  0        en              2   0.741771
# 182     0  NaN  NaN  NaN  0        en              0   0.912744
# 183     0  NaN  1.0  NaN  0        en              0   0.210352
# 184     0  NaN  1.0  NaN  0        en              1   0.783032
# 185     0  NaN  1.0  NaN  0        en              1   0.500000
# 186     0  NaN  1.0  NaN  0        en              1   0.954473
# 187     0  NaN  1.0  NaN  0        en              1   0.732618
# 188     0  NaN  1.0  NaN  0        en              0   0.210352
# 189     0  NaN  NaN  NaN  0        en              0   0.960193
# 190     0  NaN  1.0  NaN  0        en              2   0.785938
# 191     0  NaN  1.0  NaN  0        en              0   0.784477
# 192     0  NaN  1.0  NaN  0        en              0   0.829039
# 193     0  NaN  1.0  NaN  0        en              1   0.809751
# 194     0  NaN  1.0  NaN  0        en              0   0.210352
# 195     0  NaN  1.0  NaN  0        en              0   0.829039
# 196     0  NaN  1.0  NaN  0        en              0   0.210352
# 197     0  NaN  1.0  NaN  0        en              2   0.726100
# 198     0  NaN  1.0  NaN  0        en              1   0.974390
# 199     0  NaN  1.0  NaN  0        en              0   0.210352
#
# [200 rows x 44 columns]
