# %%
# code adapted from https://github.com/ageron/handson-ml/blob/master/10_introduction_to_artificial_neural_networks.ipynb

# %%
# number of neurons in the input, hidden, and output layers
n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

# %%
import tensorflow as tf

# 'placeholder' nodes to represent the training data and targets
X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# %%
import numpy as np

# function to create a neuron layer
def neuron_layer(X, n_neurons, name, activation=None):
    # name scoping for better visualization in TensorBoard if desired
    with tf.name_scope(name):
        # get the number of inputs
        n_inputs = int(X.get_shape()[1])
        
        # create the weights matrix W and initialize weights randomly
        stddev = 2 / np.sqrt(n_inputs)
        init   = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W      = tf.Variable(init, name="kernel")
        
        # instantiate and initalize biases to 0
        b = tf.Variable(tf.zeros([n_neurons]), name="bias")
        
        # subgraph for efficient computation of X.W+b
        Z = tf.matmul(X, W) + b
        
        # run activation function (e.g., ReLU) if parameter set
        if activation is not None:
            return activation(Z)
        else:
            return Z

# %%
# create a DNN with two hidden layers and a softmax output layer
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, name="hidden1",
                           activation=tf.nn.relu)
    hidden2 = neuron_layer(hidden1, n_hidden2, name="hidden2",
                           activation=tf.nn.relu)
    logits = neuron_layer(hidden2, n_outputs, name="outputs")

# using a pre-implemented library function instead...
'''
from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn"):
    hidden1 = fully_connected(X, n_hidden1, scope="hidden1")
    hidden2 = fully_connected(hidden1, n_hidden2, scope="hidden2")
    logits = fully_connected(hidden2, n_outputs, scope="outputs, activation_fn=None")
'''
# Out:
# '\nfrom tensorflow.contrib.layers import fully_connected\n\nwith tf.name_scope("dnn"):\n    hidden1 = fully_connected(X, n_hidden1, scope="hidden1")\n    hidden2 = fully_connected(hidden1, n_hidden2, scope="hidden2")\n    logits = fully_connected(hidden2, n_outputs, scope="outputs, activation_fn=None")\n'

# %%
# define cross entropy loss function
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                              logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
# instantiate gradient descent loss optimizer
with tf.name_scope("train"):
    learning_rate = 0.01
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
# specify accuracy as evaluation metric
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
# load MNIST dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# intialize variables
init = tf.global_variables_initializer()

# set number of epochs and batches
n_epochs = 200
batch_size = 50

# train the DNN
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_val = accuracy.eval(feed_dict={X: mnist.validation.images,
                                            y: mnist.validation.labels})
        print(epoch, "Train accuracy:", acc_train, "Val accuracy:", acc_val)

    # evaluate DNN performance
    X_new_scaled = mnist.test.images[:20]
    Z = logits.eval(feed_dict={X: X_new_scaled})
    y_pred = np.argmax(Z, axis=1)

    print("Predicted classes:\t", y_pred)
    print("Actual classes:\t\t", mnist.test.labels[:20])
# Out:
# 0 Train accuracy: 0.94 Val accuracy: 0.9136
# 1 Train accuracy: 0.96 Val accuracy: 0.9308
# 2 Train accuracy: 0.96 Val accuracy: 0.9396
# 3 Train accuracy: 0.96 Val accuracy: 0.947
# 4 Train accuracy: 0.98 Val accuracy: 0.9512
# 5 Train accuracy: 1.0 Val accuracy: 0.9556
# 6 Train accuracy: 0.94 Val accuracy: 0.9604
# 7 Train accuracy: 0.98 Val accuracy: 0.963
# 8 Train accuracy: 0.98 Val accuracy: 0.9636
# 9 Train accuracy: 0.9 Val accuracy: 0.9664
# 10 Train accuracy: 1.0 Val accuracy: 0.9702
# 11 Train accuracy: 0.98 Val accuracy: 0.9706
# 12 Train accuracy: 0.98 Val accuracy: 0.9722
# 13 Train accuracy: 0.96 Val accuracy: 0.9718
# 14 Train accuracy: 1.0 Val accuracy: 0.9742
# 15 Train accuracy: 1.0 Val accuracy: 0.975
# 16 Train accuracy: 0.96 Val accuracy: 0.9746
# 17 Train accuracy: 1.0 Val accuracy: 0.975
# 18 Train accuracy: 0.96 Val accuracy: 0.976
# 19 Train accuracy: 0.98 Val accuracy: 0.976
# 20 Train accuracy: 0.96 Val accuracy: 0.9758
# 21 Train accuracy: 0.98 Val accuracy: 0.9782
# 22 Train accuracy: 1.0 Val accuracy: 0.9784
# 23 Train accuracy: 1.0 Val accuracy: 0.9776
# 24 Train accuracy: 1.0 Val accuracy: 0.9788
# 25 Train accuracy: 1.0 Val accuracy: 0.9794
# 26 Train accuracy: 1.0 Val accuracy: 0.9796
# 27 Train accuracy: 1.0 Val accuracy: 0.9796
# 28 Train accuracy: 1.0 Val accuracy: 0.981
# 29 Train accuracy: 1.0 Val accuracy: 0.9808
# 30 Train accuracy: 1.0 Val accuracy: 0.9804
# 31 Train accuracy: 1.0 Val accuracy: 0.98
# 32 Train accuracy: 1.0 Val accuracy: 0.9786
# 33 Train accuracy: 0.98 Val accuracy: 0.9812
# 34 Train accuracy: 1.0 Val accuracy: 0.9802
# 35 Train accuracy: 0.98 Val accuracy: 0.9816
# 36 Train accuracy: 1.0 Val accuracy: 0.9802
# 37 Train accuracy: 1.0 Val accuracy: 0.9812
# 38 Train accuracy: 1.0 Val accuracy: 0.9814
# 39 Train accuracy: 1.0 Val accuracy: 0.9814
# 40 Train accuracy: 0.98 Val accuracy: 0.9802
# 41 Train accuracy: 1.0 Val accuracy: 0.9812
# 42 Train accuracy: 1.0 Val accuracy: 0.9812
# 43 Train accuracy: 1.0 Val accuracy: 0.982
# 44 Train accuracy: 1.0 Val accuracy: 0.9822
# 45 Train accuracy: 1.0 Val accuracy: 0.9816
# 46 Train accuracy: 1.0 Val accuracy: 0.982
# 47 Train accuracy: 1.0 Val accuracy: 0.9812
# 48 Train accuracy: 1.0 Val accuracy: 0.982
# 49 Train accuracy: 1.0 Val accuracy: 0.982
# 50 Train accuracy: 1.0 Val accuracy: 0.981
# 51 Train accuracy: 1.0 Val accuracy: 0.9812
# 52 Train accuracy: 1.0 Val accuracy: 0.9814
# 53 Train accuracy: 1.0 Val accuracy: 0.9818
# 54 Train accuracy: 1.0 Val accuracy: 0.9824
# 55 Train accuracy: 1.0 Val accuracy: 0.9822
# 56 Train accuracy: 1.0 Val accuracy: 0.9812
# 57 Train accuracy: 1.0 Val accuracy: 0.9818
# 58 Train accuracy: 1.0 Val accuracy: 0.9822
# 59 Train accuracy: 1.0 Val accuracy: 0.9822
# 60 Train accuracy: 1.0 Val accuracy: 0.9822
# 61 Train accuracy: 1.0 Val accuracy: 0.9816
# 62 Train accuracy: 1.0 Val accuracy: 0.9822
# 63 Train accuracy: 1.0 Val accuracy: 0.9814
# 64 Train accuracy: 1.0 Val accuracy: 0.9818
# 65 Train accuracy: 1.0 Val accuracy: 0.9824
# 66 Train accuracy: 1.0 Val accuracy: 0.9824
# 67 Train accuracy: 1.0 Val accuracy: 0.982
# 68 Train accuracy: 1.0 Val accuracy: 0.9824
# 69 Train accuracy: 1.0 Val accuracy: 0.9818
# 70 Train accuracy: 1.0 Val accuracy: 0.983
# 71 Train accuracy: 1.0 Val accuracy: 0.9816
# 72 Train accuracy: 1.0 Val accuracy: 0.9826
# 73 Train accuracy: 1.0 Val accuracy: 0.9818
# 74 Train accuracy: 1.0 Val accuracy: 0.982
# 75 Train accuracy: 1.0 Val accuracy: 0.9824
# 76 Train accuracy: 1.0 Val accuracy: 0.9816
# 77 Train accuracy: 1.0 Val accuracy: 0.9824
# 78 Train accuracy: 1.0 Val accuracy: 0.9816
# 79 Train accuracy: 1.0 Val accuracy: 0.982
# 80 Train accuracy: 1.0 Val accuracy: 0.9824
# 81 Train accuracy: 1.0 Val accuracy: 0.9832
# 82 Train accuracy: 1.0 Val accuracy: 0.9818
# 83 Train accuracy: 1.0 Val accuracy: 0.9816
# 84 Train accuracy: 1.0 Val accuracy: 0.9818
# 85 Train accuracy: 1.0 Val accuracy: 0.9822
# 86 Train accuracy: 1.0 Val accuracy: 0.9826
# 87 Train accuracy: 1.0 Val accuracy: 0.9824
# 88 Train accuracy: 1.0 Val accuracy: 0.9822
# 89 Train accuracy: 1.0 Val accuracy: 0.982
# 90 Train accuracy: 1.0 Val accuracy: 0.9824
# 91 Train accuracy: 1.0 Val accuracy: 0.9818
# 92 Train accuracy: 1.0 Val accuracy: 0.9818
# 93 Train accuracy: 1.0 Val accuracy: 0.9814
# 94 Train accuracy: 1.0 Val accuracy: 0.9822
# 95 Train accuracy: 1.0 Val accuracy: 0.9816
# 96 Train accuracy: 1.0 Val accuracy: 0.9814
# 97 Train accuracy: 1.0 Val accuracy: 0.9818
# 98 Train accuracy: 1.0 Val accuracy: 0.9824
# 99 Train accuracy: 1.0 Val accuracy: 0.983
# 100 Train accuracy: 1.0 Val accuracy: 0.9828
# 101 Train accuracy: 1.0 Val accuracy: 0.9814
# 102 Train accuracy: 1.0 Val accuracy: 0.9828
# 103 Train accuracy: 1.0 Val accuracy: 0.9826
# 104 Train accuracy: 1.0 Val accuracy: 0.9822
# 105 Train accuracy: 1.0 Val accuracy: 0.9812
# 106 Train accuracy: 1.0 Val accuracy: 0.9822
# 107 Train accuracy: 1.0 Val accuracy: 0.9826
# 108 Train accuracy: 1.0 Val accuracy: 0.9828
# 109 Train accuracy: 1.0 Val accuracy: 0.982
# 110 Train accuracy: 1.0 Val accuracy: 0.982
# 111 Train accuracy: 1.0 Val accuracy: 0.9818
# 112 Train accuracy: 1.0 Val accuracy: 0.9824
# 113 Train accuracy: 1.0 Val accuracy: 0.9818
# 114 Train accuracy: 1.0 Val accuracy: 0.9824
# 115 Train accuracy: 1.0 Val accuracy: 0.9816
# 116 Train accuracy: 1.0 Val accuracy: 0.9824
# 117 Train accuracy: 1.0 Val accuracy: 0.9828
# 118 Train accuracy: 1.0 Val accuracy: 0.9806
# 119 Train accuracy: 1.0 Val accuracy: 0.9814
# 120 Train accuracy: 1.0 Val accuracy: 0.9822
# 121 Train accuracy: 1.0 Val accuracy: 0.982
# 122 Train accuracy: 1.0 Val accuracy: 0.9822
# 123 Train accuracy: 1.0 Val accuracy: 0.9826
# 124 Train accuracy: 1.0 Val accuracy: 0.9822
# 125 Train accuracy: 1.0 Val accuracy: 0.9816
# 126 Train accuracy: 1.0 Val accuracy: 0.9818
# 127 Train accuracy: 1.0 Val accuracy: 0.9824
# 128 Train accuracy: 1.0 Val accuracy: 0.9816
# 129 Train accuracy: 1.0 Val accuracy: 0.9816
# 130 Train accuracy: 1.0 Val accuracy: 0.9824
# 131 Train accuracy: 1.0 Val accuracy: 0.9818
# 132 Train accuracy: 1.0 Val accuracy: 0.982
# 133 Train accuracy: 1.0 Val accuracy: 0.9824
# 134 Train accuracy: 1.0 Val accuracy: 0.9826
# 135 Train accuracy: 1.0 Val accuracy: 0.9816
# 136 Train accuracy: 1.0 Val accuracy: 0.9814
# 137 Train accuracy: 1.0 Val accuracy: 0.982
# 138 Train accuracy: 1.0 Val accuracy: 0.9824
# 139 Train accuracy: 1.0 Val accuracy: 0.9828
# 140 Train accuracy: 1.0 Val accuracy: 0.9824
# 141 Train accuracy: 1.0 Val accuracy: 0.9822
# 142 Train accuracy: 1.0 Val accuracy: 0.9822
# 143 Train accuracy: 1.0 Val accuracy: 0.9822
# 144 Train accuracy: 1.0 Val accuracy: 0.9818
# 145 Train accuracy: 1.0 Val accuracy: 0.9818
# 146 Train accuracy: 1.0 Val accuracy: 0.9816
# 147 Train accuracy: 1.0 Val accuracy: 0.9828
# 148 Train accuracy: 1.0 Val accuracy: 0.9824
# 149 Train accuracy: 1.0 Val accuracy: 0.982
# 150 Train accuracy: 1.0 Val accuracy: 0.9826
# 151 Train accuracy: 1.0 Val accuracy: 0.9822
# 152 Train accuracy: 1.0 Val accuracy: 0.9814
# 153 Train accuracy: 1.0 Val accuracy: 0.9824
# 154 Train accuracy: 1.0 Val accuracy: 0.9822
# 155 Train accuracy: 1.0 Val accuracy: 0.982
# 156 Train accuracy: 1.0 Val accuracy: 0.9822
# 157 Train accuracy: 1.0 Val accuracy: 0.9812
# 158 Train accuracy: 1.0 Val accuracy: 0.9822
# 159 Train accuracy: 1.0 Val accuracy: 0.982
# 160 Train accuracy: 1.0 Val accuracy: 0.9822
# 161 Train accuracy: 1.0 Val accuracy: 0.9824
# 162 Train accuracy: 1.0 Val accuracy: 0.982
# 163 Train accuracy: 1.0 Val accuracy: 0.9818
# 164 Train accuracy: 1.0 Val accuracy: 0.9824
# 165 Train accuracy: 1.0 Val accuracy: 0.9822
# 166 Train accuracy: 1.0 Val accuracy: 0.9822
# 167 Train accuracy: 1.0 Val accuracy: 0.9822
# 168 Train accuracy: 1.0 Val accuracy: 0.9826
# 169 Train accuracy: 1.0 Val accuracy: 0.9822
# 170 Train accuracy: 1.0 Val accuracy: 0.982
# 171 Train accuracy: 1.0 Val accuracy: 0.9822
# 172 Train accuracy: 1.0 Val accuracy: 0.9822
# 173 Train accuracy: 1.0 Val accuracy: 0.9824
# 174 Train accuracy: 1.0 Val accuracy: 0.9824
# 175 Train accuracy: 1.0 Val accuracy: 0.9824
# 176 Train accuracy: 1.0 Val accuracy: 0.982
# 177 Train accuracy: 1.0 Val accuracy: 0.9818
# 178 Train accuracy: 1.0 Val accuracy: 0.9824
# 179 Train accuracy: 1.0 Val accuracy: 0.9818
# 180 Train accuracy: 1.0 Val accuracy: 0.9818
# 181 Train accuracy: 1.0 Val accuracy: 0.982
# 182 Train accuracy: 1.0 Val accuracy: 0.9822
# 183 Train accuracy: 1.0 Val accuracy: 0.9824
# 184 Train accuracy: 1.0 Val accuracy: 0.982
# 185 Train accuracy: 1.0 Val accuracy: 0.9818
# 186 Train accuracy: 1.0 Val accuracy: 0.982
# 187 Train accuracy: 1.0 Val accuracy: 0.982
# 188 Train accuracy: 1.0 Val accuracy: 0.9822
# 189 Train accuracy: 1.0 Val accuracy: 0.9824
# 190 Train accuracy: 1.0 Val accuracy: 0.982
# 191 Train accuracy: 1.0 Val accuracy: 0.982
# 192 Train accuracy: 1.0 Val accuracy: 0.982
# 193 Train accuracy: 1.0 Val accuracy: 0.982
# 194 Train accuracy: 1.0 Val accuracy: 0.9822
# 195 Train accuracy: 1.0 Val accuracy: 0.982
# 196 Train accuracy: 1.0 Val accuracy: 0.982
# 197 Train accuracy: 1.0 Val accuracy: 0.982
# 198 Train accuracy: 1.0 Val accuracy: 0.9822
# 199 Train accuracy: 1.0 Val accuracy: 0.9822
# Predicted classes:	 [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
# Actual classes:		 [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
